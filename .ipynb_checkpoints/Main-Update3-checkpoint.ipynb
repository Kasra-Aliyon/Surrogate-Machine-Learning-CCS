# %% [markdown]
# #### Import necessary packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("data\\data.xlsx")
print("Number of instance in the dataset is :{}".format(len(df)))
# Out:
# Number of instance in the dataset is :9720

# %%
df = df[df["LMTD"] > 0]
print("Number of instance in the dataset is :{}".format(len(df)))
# Out:
# Number of instance in the dataset is :8480

# %%
# Drop the data points with non positive chilling Duty
df = df[df["LA Chilling Duty"] >= 0]
print("Number of instance in the dataset is :{}".format(len(df)))
# Out:
# Number of instance in the dataset is :5704

# %%
df["SCD (MJ/kg)"] = (0.001 * df["LA Chilling Duty"]) / df["Captured CO2 (kg/h)"]

# %% [markdown]
# ## Exploring the data

# %%
df.columns
# Out:
# Index(['State', 'FG Massflow (kg/h)', 'Flue gas CO2 cons', 'FG Temperature',
#        'Lean Amine Mass flow (kg/h)', 'Lean Amine Temperature',
#        'WWT Flow rate', 'WWB Flow rate', 'RA2Reg-Temperature',
#        'Reboiler Duty (kJ/h)', 'LA Chilling Duty', 'WWT Cooling Duty',
#        'WWT Cooling Duty2', 'MEA Emission PPM', 'CO2 Mass Flow @ Off Gas',
#        'MEA Emission', 'FG Flue Rate (Sm3/h)', 'L/G (kg/kg)', 'L/G (kg/Sm3)',
#        'Lean Loading', 'Captured CO2 (kg/h)', 'CO2 Capture Efficiency',
#        'Rich Loading', 'RA Flow Rate', 'RA Temp after Abs', 'Reboiler Duty',
#        'Condensor Duty (kJ/h)', 'SRD (MJ/kg CO2)', 'Condensor Specific Duty',
#        'CO2 Product purity', 'CO2 Production Mass Flow', 'Reg Bttm Temp',
#        'Reg Bttm Flow Rate', 'LA after HE', 'Left Min Apprch',
#        'Right Min Appr', 'LMTD', 'MEA Makeup', 'Abs Height', 'SCD (MJ/kg)'],
#       dtype='object')

# %%
df.describe().transpose()
# Out:
#                               count          mean           std           min  \
# FG Massflow (kg/h)           5704.0  7.207411e+04  1.031939e+01  7.207000e+04
# Flue gas CO2 cons            5704.0  8.359599e-02  3.298276e-02  3.600000e-02
# FG Temperature               5704.0  3.695126e+01  1.178362e+01  2.000000e+01
# Lean Amine Mass flow (kg/h)  5704.0  1.351625e+05  8.233373e+04  4.160000e+04
# Lean Amine Temperature       5704.0  3.728787e+01  7.417124e+00  3.000000e+01
# WWT Flow rate                5704.0  5.500000e+04  0.000000e+00  5.500000e+04
# WWB Flow rate                5704.0  5.500863e+04  3.439796e+00  5.500000e+04
# RA2Reg-Temperature           5704.0  1.043051e+02  1.206691e+00  1.030000e+02
# Reboiler Duty (kJ/h)         5704.0  3.078945e+07  1.236984e+07  1.000000e+07
# LA Chilling Duty             5704.0  6.601097e+06  6.968066e+06  1.936000e+03
# WWT Cooling Duty             5704.0  3.128264e+06  1.346168e+06  3.070000e+05
# WWT Cooling Duty2            5704.0  4.359905e+06  1.451078e+06  6.506000e+05
# MEA Emission PPM             5704.0  1.613702e-01  3.216315e-01  1.726000e-04
# CO2 Mass Flow @ Off Gas      5704.0  2.207056e+03  1.994389e+03  1.221000e+01
# MEA Emission                 5704.0  1.613925e-07  3.217061e-07  1.726000e-10
# FG Flue Rate (Sm3/h)         5704.0  5.789569e+04  1.036741e+03  5.638000e+04
# L/G (kg/kg)                  5704.0  1.875638e+00  1.142761e+00  5.772000e-01
# L/G (kg/Sm3)                 5704.0  2.352114e+00  1.458413e+00  7.002000e-01
# Lean Loading                 5704.0  2.049223e-01  7.820774e-02  7.095000e-02
# Captured CO2 (kg/h)          5704.0  6.737296e+03  2.938513e+03  2.502000e+03
# CO2 Capture Efficiency       5704.0  7.700561e+01  1.879548e+01  2.872000e+01
# Rich Loading                 5704.0  4.699677e-01  3.968865e-02  3.232000e-01
# RA Flow Rate                 5704.0  1.404476e+05  8.445365e+04  4.316000e+04
# RA Temp after Abs            5704.0  3.836125e+01  7.370878e+00  2.088000e+01
# Reboiler Duty                5704.0  3.078945e+07  1.236984e+07  1.000000e+07
# Condensor Duty (kJ/h)        5704.0  1.284328e+07  6.109412e+06  2.917000e+06
# SRD (MJ/kg CO2)              5704.0  4.765017e+00  1.247572e+00  2.941000e+00
# Condensor Specific Duty      5704.0  2.081913e+00  1.090142e+00  1.120000e+00
# CO2 Product purity           5704.0  9.856748e-01  5.815067e-04  9.828000e-01
# CO2 Production Mass Flow     5704.0  6.781539e+03  2.959779e+03  2.515000e+03
# Reg Bttm Temp                5704.0  1.205428e+02  2.568666e+00  1.108000e+02
# Reg Bttm Flow Rate           5704.0  1.336667e+05  8.205559e+04  4.020000e+04
# LA after HE                  5704.0  5.040206e+01  9.103813e+00  2.997000e+01
# Left Min Apprch              5704.0  1.204087e+01  5.714874e+00  4.490000e-02
# Right Min Appr               5704.0  1.623721e+01  2.661992e+00  7.289000e+00
# LMTD                         5704.0  1.382633e+01  4.264904e+00  1.663000e+00
# MEA Makeup                   5704.0  1.354874e+00  3.618611e+00  0.000000e+00
# Abs Height                   5704.0  1.749404e+01  4.864350e+00  1.200000e+01
# SCD (MJ/kg)                  5704.0  8.970348e-01  7.206116e-01  2.281942e-04
#
#                                       25%           50%           75%  \
# FG Massflow (kg/h)           7.207000e+04  7.207000e+04  7.207000e+04
# Flue gas CO2 cons            5.950000e-02  9.050000e-02  1.088000e-01
# FG Temperature               2.000000e+01  3.500000e+01  5.000000e+01
# Lean Amine Mass flow (kg/h)  8.120000e+04  1.010000e+05  1.670000e+05
# Lean Amine Temperature       3.000000e+01  4.000000e+01  4.000000e+01
# WWT Flow rate                5.500000e+04  5.500000e+04  5.500000e+04
# WWB Flow rate                5.501000e+04  5.501000e+04  5.501000e+04
# RA2Reg-Temperature           1.030000e+02  1.045000e+02  1.060000e+02
# Reboiler Duty (kJ/h)         2.000000e+07  3.000000e+07  4.400000e+07
# LA Chilling Duty             1.786000e+06  3.944500e+06  8.888750e+06
# WWT Cooling Duty             2.110000e+06  2.908000e+06  4.105500e+06
# WWT Cooling Duty2            3.291750e+06  4.200000e+06  5.474500e+06
# MEA Emission PPM             2.091750e-03  4.767000e-03  1.937250e-01
# CO2 Mass Flow @ Off Gas      4.480250e+02  1.627000e+03  3.586500e+03
# MEA Emission                 2.091750e-09  4.767000e-09  1.937250e-07
# FG Flue Rate (Sm3/h)         5.709000e+04  5.770000e+04  5.864000e+04
# L/G (kg/kg)                  1.127000e+00  1.401000e+00  2.313000e+00
# L/G (kg/Sm3)                 1.367000e+00  1.735000e+00  2.956000e+00
# Lean Loading                 1.396000e-01  1.968500e-01  2.657000e-01
# Captured CO2 (kg/h)          3.915000e+03  6.284000e+03  9.184500e+03
# CO2 Capture Efficiency       6.184000e+01  8.117500e+01  9.379000e+01
# Rich Loading                 4.607750e-01  4.883000e-01  4.948000e-01
# RA Flow Rate                 8.312750e+04  1.053000e+05  1.763000e+05
# RA Temp after Abs            3.349000e+01  3.686500e+01  4.346250e+01
# Reboiler Duty                2.000000e+07  3.000000e+07  4.400000e+07
# Condensor Duty (kJ/h)        8.131000e+06  1.209000e+07  1.634000e+07
# SRD (MJ/kg CO2)              3.822000e+00  4.385000e+00  5.422000e+00
# Condensor Specific Duty      1.277000e+00  1.612000e+00  2.494000e+00
# CO2 Product purity           9.854000e-01  9.858000e-01  9.861000e-01
# CO2 Production Mass Flow     3.943000e+03  6.320000e+03  9.249500e+03
# Reg Bttm Temp                1.192000e+02  1.214000e+02  1.226000e+02
# Reg Bttm Flow Rate           7.872000e+04  9.907000e+04  1.660000e+05
# LA after HE                  4.365000e+01  4.986000e+01  5.678000e+01
# Left Min Apprch              7.618750e+00  1.196000e+01  1.647250e+01
# Right Min Appr               1.459000e+01  1.674000e+01  1.830000e+01
# LMTD                         1.092000e+01  1.423000e+01  1.725000e+01
# MEA Makeup                   0.000000e+00  0.000000e+00  0.000000e+00
# Abs Height                   1.200000e+01  1.800000e+01  2.400000e+01
# SCD (MJ/kg)                  3.518960e-01  7.169321e-01  1.256964e+00
#
#                                       max
# FG Massflow (kg/h)           7.210000e+04
# Flue gas CO2 cons            1.324000e-01
# FG Temperature               5.000000e+01
# Lean Amine Mass flow (kg/h)  3.000000e+05
# Lean Amine Temperature       5.000000e+01
# WWT Flow rate                5.500000e+04
# WWB Flow rate                5.501000e+04
# RA2Reg-Temperature           1.060000e+02
# Reboiler Duty (kJ/h)         5.200000e+07
# LA Chilling Duty             3.744000e+07
# WWT Cooling Duty             7.120000e+06
# WWT Cooling Duty2            8.200000e+06
# MEA Emission PPM             2.309000e+00
# CO2 Mass Flow @ Off Gas      8.572000e+03
# MEA Emission                 2.310000e-06
# FG Flue Rate (Sm3/h)         5.941000e+04
# L/G (kg/kg)                  4.163000e+00
# L/G (kg/Sm3)                 5.321000e+00
# Lean Loading                 3.924000e-01
# Captured CO2 (kg/h)          1.360000e+04
# CO2 Capture Efficiency       9.969000e+01
# Rich Loading                 5.089000e-01
# RA Flow Rate                 3.131000e+05
# RA Temp after Abs            5.498000e+01
# Reboiler Duty                5.200000e+07
# Condensor Duty (kJ/h)        3.359000e+07
# SRD (MJ/kg CO2)              8.376000e+00
# Condensor Specific Duty      5.885000e+00
# CO2 Product purity           9.864000e-01
# CO2 Production Mass Flow     1.370000e+04
# Reg Bttm Temp                1.234000e+02
# Reg Bttm Flow Rate           3.000000e+05
# LA after HE                  7.299000e+01
# Left Min Apprch              2.452000e+01
# Right Min Appr               2.035000e+01
# LMTD                         2.218000e+01
# MEA Makeup                   3.325000e+01
# Abs Height                   2.400000e+01
# SCD (MJ/kg)                  3.725383e+00

# %%
df.groupby(["Flue gas CO2 cons"]).mean()["SRD (MJ/kg CO2)"]
# Out:
# Flue gas CO2 cons
# 0.0360    5.918239
# 0.0595    4.781794
# 0.0838    4.705801
# 0.0905    4.611641
# 0.1088    4.251134
# 0.1324    4.023896
# Name: SRD (MJ/kg CO2), dtype: float64

# %%
df.groupby(["Flue gas CO2 cons", "Abs Height"]).std()["SRD (MJ/kg CO2)"]
# Out:
# Flue gas CO2 cons  Abs Height
# 0.0360             12            1.489780
#                    18            1.405795
#                    24            1.392912
# 0.0595             12            1.141965
#                    18            1.198181
#                    24            1.203629
# 0.0838             12            1.220313
#                    18            1.225402
#                    24            1.252473
# 0.0905             12            0.846821
#                    18            0.793717
#                    24            0.803286
# 0.1088             12            0.740948
#                    18            0.698323
#                    24            0.721084
# 0.1324             12            0.721200
#                    18            0.697385
#                    24            0.704601
# Name: SRD (MJ/kg CO2), dtype: float64

# %%
df.groupby(["Flue gas CO2 cons"]).describe()[["CO2 Capture Efficiency","SRD (MJ/kg CO2)"]]
# Out:
#                   CO2 Capture Efficiency                               \
#                                    count       mean        std    min
# Flue gas CO2 cons
# 0.0360                            1209.0  91.599926   9.425238  62.86
# 0.0595                             867.0  71.267578  18.092525  39.40
# 0.0838                             755.0  51.638927  14.298897  28.72
# 0.0905                             916.0  85.807533  11.907557  53.81
# 0.1088                             998.0  80.107766  14.740328  45.65
# 0.1324                             959.0  72.129353  16.093976  38.30
#
#                                                    SRD (MJ/kg CO2)            \
#                        25%     50%      75%    max           count      mean
# Flue gas CO2 cons
# 0.0360             88.6800  94.410  98.6500  99.69          1209.0  5.918239
# 0.0595             56.1950  74.190  89.1450  99.40           867.0  4.781794
# 0.0838             40.7100  50.450  62.5050  81.08           755.0  4.705801
# 0.0905             79.0200  88.470  95.1900  99.47           916.0  4.611641
# 0.1088             68.7825  83.555  93.1225  99.20           998.0  4.251134
# 0.1324             59.2500  74.370  86.6600  97.79           959.0  4.023896
#
#
#                         std    min      25%     50%      75%    max
# Flue gas CO2 cons
# 0.0360             1.433304  3.262  4.77500  5.9180  7.13400  8.376
# 0.0595             1.178407  3.135  3.86650  4.4600  5.14250  8.017
# 0.0838             1.230397  3.124  3.79700  4.2760  5.10900  7.942
# 0.0905             0.820614  3.088  3.90700  4.6205  5.41225  6.443
# 0.1088             0.726061  2.946  3.69025  4.0680  4.63475  6.361
# 0.1324             0.712473  2.941  3.56400  3.8750  4.22550  6.312

# %% [markdown]
# ### Visualization

# %%
sns.displot(df["CO2 Capture Efficiency"], bins=15, kde=True)

# %%
sns.displot(df["SRD (MJ/kg CO2)"], bins=15, kde=True)

# %%
sns.displot(df["Lean Loading"], bins=15, kde=True)

# %%
sns.displot(df["Rich Loading"], bins=20, kde=True)

# %%
sns.displot(df["Condensor Specific Duty"], bins=20, kde=True)

# %%
sns.displot(df["CO2 Product purity"], bins=20, kde=True)

# %%
sns.jointplot(data= df[ (df["CO2 Capture Efficiency"] >= 85) & (df["CO2 Capture Efficiency"] <= 90)] , 
              x= "LMTD", 
              y="SRD (MJ/kg CO2)",
              hue="Flue gas CO2 cons",
              cmap="Blues"
             )

# %%
sns.displot(df["LA Chilling Duty"], bins=20, kde=True)

# %%
sns.displot(df["SCD (MJ/kg)"], bins=15, kde=True)

# %% [markdown]
# # Machine Learning

# %% [markdown]
# #### Import common Machine Learning Packages

# %%
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from joblib import dump, load

# %% [markdown]
# #### Define the inputs & outputs

# %%
# XA Represents the data for Advanced Design
XA = df[["FG Temperature", "Lean Loading",'Lean Amine Temperature','L/G (kg/kg)','Flue gas CO2 cons','CO2 Capture Efficiency','LMTD','Abs Height']]

# %%
# X2 Represents the data for Naive Design
XN = df[["FG Temperature", "Lean Loading",'Lean Amine Temperature','L/G (kg/kg)','Flue gas CO2 cons','CO2 Capture Efficiency']]

# %%
y = df[["SRD (MJ/kg CO2)", "Condensor Specific Duty", "SCD (MJ/kg)"]]

# %%
XA_train, XA_test, y_train, y_test = train_test_split(XA, y, test_size=0.30, random_state=211)
XN_train, XN_test, y_train, y_test = train_test_split(XN, y, test_size=0.30, random_state=211)

# %% [markdown]
# #### Define the dataframe function for performance evaluation

# %%
performance_SRD = pd.DataFrame(columns=["name","R^2_A", "MAE_A", "MAPE_A", "RMSE_A", "R^2_N", "MAE_N", "MAPE_N", "RMSE_N"])
performance_ConSD = pd.DataFrame(columns=["name","R^2_A", "MAE_A", "MAPE_A", "RMSE_A", "R^2_N", "MAE_N", "MAPE_N", "RMSE_N"])
performance_SCD = pd.DataFrame(columns=["name","R^2_A", "MAE_A", "MAPE_A", "RMSE_A", "R^2_N", "MAE_N", "MAPE_N", "RMSE_N"])

# %%
def evaldf_SRD(A_pred, N_pred, model_name):
    
    row = pd.DataFrame(
                        {
                         "name": str(str(model_name) + '_SRD'),
                         "R^2_A": r2_score(y_test["SRD (MJ/kg CO2)"], A_pred[: , 0]),
                         "MAE_A": mean_absolute_error(y_test["SRD (MJ/kg CO2)"], A_pred[: , 0]),
                         "MAPE_A": mean_absolute_percentage_error(y_test["SRD (MJ/kg CO2)"], A_pred[: , 0]),
                         "RMSE_A": np.sqrt(mean_squared_error(y_test["SRD (MJ/kg CO2)"], A_pred[: , 0])),
                         "R^2_N": r2_score(y_test["SRD (MJ/kg CO2)"], N_pred[: , 0]),
                         "MAE_N": mean_absolute_error(y_test["SRD (MJ/kg CO2)"], N_pred[: , 0]),
                         "MAPE_N": mean_absolute_percentage_error(y_test["SRD (MJ/kg CO2)"], N_pred[: , 0]),
                         "RMSE_N": np.sqrt(mean_squared_error(y_test["SRD (MJ/kg CO2)"], N_pred[: , 0]))
                        }
            , index=[0])
    
    global performance_SRD
    
    performance_SRD = pd.concat([performance_SRD, row], ignore_index=True)

# %%
def evaldf_ConSD(A_pred, N_pred, model_name):
    
    row = pd.DataFrame(
                        {
                         "name": str(str(model_name) + '_ConsSD'),
                         "R^2_A": r2_score(y_test["Condensor Specific Duty"], A_pred[: , 1]),
                         "MAE_A": mean_absolute_error(y_test["Condensor Specific Duty"], A_pred[: , 1]),
                         "MAPE_A": mean_absolute_percentage_error(y_test["Condensor Specific Duty"], A_pred[: , 1]),
                         "RMSE_A": np.sqrt(mean_squared_error(y_test["Condensor Specific Duty"], A_pred[: , 1])),
                         "R^2_N": r2_score(y_test["Condensor Specific Duty"], N_pred[: , 1]),
                         "MAE_N": mean_absolute_error(y_test["Condensor Specific Duty"], N_pred[: , 1]),
                         "MAPE_N": mean_absolute_percentage_error(y_test["Condensor Specific Duty"], N_pred[: , 1]),
                         "RMSE_N": np.sqrt(mean_squared_error(y_test["Condensor Specific Duty"], N_pred[: , 1]))
                        }
            , index=[0])
        
    global performance_ConSD
    
    performance_ConSD = pd.concat([performance_ConSD, row], ignore_index=True)

# %%
def evaldf_SCD(A_pred, N_pred, model_name):
    
    row = pd.DataFrame(
                        {
                         "name": str(str(model_name) + '_SCD'),
                         "R^2_A": r2_score(y_test["SCD (MJ/kg)"], A_pred[: , 2]),
                         "MAE_A": mean_absolute_error(y_test["SCD (MJ/kg)"], A_pred[: , 2]),
                         "MAPE_A": mean_absolute_percentage_error(y_test["SCD (MJ/kg)"], A_pred[: , 2]),
                         "RMSE_A": np.sqrt(mean_squared_error(y_test["SCD (MJ/kg)"], A_pred[: , 2])),
                         "R^2_N": r2_score(y_test["SCD (MJ/kg)"], N_pred[: , 2]),
                         "MAE_N": mean_absolute_error(y_test["SCD (MJ/kg)"], N_pred[: , 2]),
                         "MAPE_N": mean_absolute_percentage_error(y_test["SCD (MJ/kg)"], N_pred[: , 2]),
                         "RMSE_N": np.sqrt(mean_squared_error(y_test["SCD (MJ/kg)"], N_pred[: , 2]))
                        }
            , index=[0])
    
    global performance_SCD
     
    performance_SCD = pd.concat([performance_SCD, row], ignore_index=True)

# %% [markdown]
# #### Define the ploting function

# %%
def plot_result(A_pred, N_pred):
    fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15,15), dpi=300)
    fig = plt.figure()

    axes[0,0].plot(np.arange(2,10), np.arange(2,10), color = "red")
    axes[0,0].scatter(y_test["SRD (MJ/kg CO2)"], A_pred[: , 0])
    axes[0,1].plot(np.arange(2,10), np.arange(2,10), color = "red")
    axes[0,1].scatter(y_test["SRD (MJ/kg CO2)"], N_pred[: , 0])

    axes[1,0].plot(np.arange(0,7), np.arange(0,7), color = "red")
    axes[1,0].scatter(y_test['Condensor Specific Duty'], A_pred[: , 1])
    axes[1,1].plot(np.arange(0,7), np.arange(0,7), color = "red")
    axes[1,1].scatter(y_test['Condensor Specific Duty'], N_pred[: , 1])

    axes[2,0].plot(np.arange(0,5), np.arange(0,5), color = "red")
    axes[2,0].scatter(y_test['SCD (MJ/kg)'], A_pred[: , 2])
    axes[2,1].plot(np.arange(0,5), np.arange(0,5), color = "red")
    axes[2,1].scatter(y_test['SCD (MJ/kg)'], N_pred[: , 2])
    plt.show()

# %%
rs = 211

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DTmodelA = MultiOutputRegressor(DecisionTreeRegressor(random_state=rs)).fit(XA_train, y_train)
DTmodelN = MultiOutputRegressor(DecisionTreeRegressor(random_state=rs)).fit(XN_train, y_train)

# %%
DTmodelA_pred = DTmodelA.predict(XA_test)
DTmodelN_pred = DTmodelN.predict(XN_test)

# %%
evaldf_SRD(DTmodelA_pred, DTmodelN_pred, 'DT')
evaldf_ConSD(DTmodelA_pred, DTmodelN_pred, 'DT')
evaldf_SCD(DTmodelA_pred, DTmodelN_pred, 'DT')

# %%
plot_result(DTmodelA_pred, DTmodelN_pred)

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RFmodelA = MultiOutputRegressor(RandomForestRegressor(max_depth=20,
                                                      max_features=6,
                                                      n_estimators=180,
                                                      n_jobs=-1,
                                                      random_state=rs)
                                ).fit(XA_train, y_train)

RFmodelN = MultiOutputRegressor(RandomForestRegressor(max_depth=20,
                                                      max_features=6,
                                                      n_estimators=180,
                                                      n_jobs=-1,
                                                      random_state=rs)
                               ).fit(XN_train, y_train)

# %%
RFmodelA_pred = RFmodelA.predict(XA_test)
RFmodelN_pred = RFmodelN.predict(XN_test)

# %%
evaldf_SRD(RFmodelA_pred, RFmodelN_pred, 'RF')
evaldf_ConSD(RFmodelA_pred, RFmodelN_pred, 'RF')
evaldf_SCD(RFmodelA_pred, RFmodelN_pred, 'RF')

# %%
plot_result(RFmodelA_pred, RFmodelN_pred)

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBRegressor

# %%
XGmodelA = MultiOutputRegressor(XGBRegressor(max_depth=10,
                                             learnin_rate=0.05,
                                             subsample=0.8,
                                             n_estimators=250,
                                             n_jobs=-1,
                                             random_state=rs)
                               ).fit(XA_train, y_train)

XGmodelN = MultiOutputRegressor(XGBRegressor(max_depth=10,
                                             learnin_rate=0.05,
                                             subsample=0.8,
                                             n_estimators=250,
                                             n_jobs=-1,
                                             random_state=rs)
                               ).fit(XN_train, y_train)
# Out:
# [15:59:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "learnin_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:59:49] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "learnin_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:59:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "learnin_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:59:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "learnin_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:59:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "learnin_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [15:59:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "learnin_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
XGmodelA_pred = XGmodelA.predict(XA_test)
XGmodelN_pred = XGmodelN.predict(XN_test)

# %%
evaldf_SRD(XGmodelA_pred, XGmodelN_pred, 'XG')
evaldf_ConSD(XGmodelA_pred, XGmodelN_pred, 'XG')
evaldf_SCD(XGmodelA_pred, XGmodelN_pred, 'XG')

# %%
plot_result(XGmodelA_pred, XGmodelN_pred)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVR

# %%
SVmodelA = MultiOutputRegressor(Pipeline([('scaler', StandardScaler()),
                                          ('svrA', SVR(C=100, degree=2, gamma= 'auto', kernel ='rbf'))])
                               ).fit(XA_train, y_train)

SVmodelN = MultiOutputRegressor(Pipeline([('scaler', StandardScaler()),
                                          ('svrN', SVR(C=100, degree=2, gamma= 'auto', kernel ='rbf'))])
                               ).fit(XN_train, y_train)

# %%
SVmodelA_pred = SVmodelA.predict(XA_test)
SVmodelN_pred = SVmodelN.predict(XN_test)

# %%
evaldf_SRD(SVmodelA_pred, SVmodelN_pred, 'SV')
evaldf_ConSD(SVmodelA_pred, SVmodelN_pred, 'SV')
evaldf_SCD(SVmodelA_pred, SVmodelN_pred, 'SV')

# %%
plot_result(SVmodelA_pred, SVmodelN_pred)

# %% [markdown]
# ## DNN

# %%
import tensorflow as tf

# %%
scalerA = StandardScaler()
scalerA.fit(XA_train)
XA_train_s = scalerA.transform(XA_train)
XA_test_s = scalerA.transform(XA_test)

# %%
scalerN = StandardScaler()
scalerN.fit(XN_train)
XN_train_s = scalerN.transform(XN_train)
XN_test_s = scalerN.transform(XN_test)

# %%
np.random.seed(rs)
tf.random.set_seed(rs)

# %%
DNmodelA = tf.keras.Sequential()

DNmodelA.add(tf.keras.layers.Dense(22, input_dim=XA_train_s.shape[1], activation='tanh'))
DNmodelA.add(tf.keras.layers.Dense(26, activation='tanh'))
DNmodelA.add(tf.keras.layers.Dense(30, activation='tanh'))
DNmodelA.add(tf.keras.layers.Dense(30, activation='tanh'))
DNmodelA.add(tf.keras.layers.Dense(30, activation='tanh'))
DNmodelA.add(tf.keras.layers.Dense(3))

DNmodelA.compile(loss="mean_squared_error", optimizer="adam")

DNmodelA.fit(XA_train_s, y_train, epochs= 150)
# Out:
# Epoch 1/150
# 125/125 [==============================] - 0s 1ms/step - loss: 3.2238
# Epoch 2/150
# 125/125 [==============================] - 0s 843us/step - loss: 0.4089
# Epoch 3/150
# 125/125 [==============================] - 0s 794us/step - loss: 0.2881
# Epoch 4/150
# 125/125 [==============================] - 0s 822us/step - loss: 0.1931
# Epoch 5/150
# 125/125 [==============================] - 0s 850us/step - loss: 0.1259
# Epoch 6/150
# 125/125 [==============================] - 0s 780us/step - loss: 0.0831
# Epoch 7/150
# 125/125 [==============================] - 0s 744us/step - loss: 0.0623
# Epoch 8/150
# 125/125 [==============================] - 0s 820us/step - loss: 0.0507
# Epoch 9/150
# 125/125 [==============================] - 0s 801us/step - loss: 0.0416
# Epoch 10/150
# 125/125 [==============================] - 0s 768us/step - loss: 0.0339
# Epoch 11/150
# 125/125 [==============================] - 0s 740us/step - loss: 0.0292
# Epoch 12/150
# 125/125 [==============================] - 0s 803us/step - loss: 0.0255
# Epoch 13/150
# 125/125 [==============================] - 0s 808us/step - loss: 0.0233
# Epoch 14/150
# 125/125 [==============================] - 0s 803us/step - loss: 0.0198
# Epoch 15/150
# 125/125 [==============================] - 0s 796us/step - loss: 0.0186
# Epoch 16/150
# 125/125 [==============================] - 0s 832us/step - loss: 0.0171
# Epoch 17/150
# 125/125 [==============================] - 0s 771us/step - loss: 0.0155
# Epoch 18/150
# 125/125 [==============================] - 0s 726us/step - loss: 0.0142
# Epoch 19/150
# 125/125 [==============================] - 0s 793us/step - loss: 0.0136
# Epoch 20/150
# 125/125 [==============================] - 0s 828us/step - loss: 0.0135
# Epoch 21/150
# 125/125 [==============================] - 0s 800us/step - loss: 0.0124
# Epoch 22/150
# 125/125 [==============================] - 0s 781us/step - loss: 0.0118
# Epoch 23/150
# 125/125 [==============================] - 0s 798us/step - loss: 0.0112
# Epoch 24/150
# 125/125 [==============================] - 0s 803us/step - loss: 0.0108
# Epoch 25/150
# 125/125 [==============================] - 0s 837us/step - loss: 0.0107
# Epoch 26/150
# 125/125 [==============================] - 0s 797us/step - loss: 0.0094
# Epoch 27/150
# 125/125 [==============================] - 0s 743us/step - loss: 0.0093
# Epoch 28/150
# 125/125 [==============================] - 0s 823us/step - loss: 0.0091
# Epoch 29/150
# 125/125 [==============================] - 0s 833us/step - loss: 0.0084
# Epoch 30/150
# 125/125 [==============================] - 0s 767us/step - loss: 0.0080
# Epoch 31/150
# 125/125 [==============================] - 0s 816us/step - loss: 0.0097
# Epoch 32/150
# 125/125 [==============================] - 0s 841us/step - loss: 0.0082
# Epoch 33/150
# 125/125 [==============================] - 0s 788us/step - loss: 0.0080
# Epoch 34/150
# 125/125 [==============================] - 0s 765us/step - loss: 0.0082
# Epoch 35/150
# 125/125 [==============================] - 0s 914us/step - loss: 0.0079
# Epoch 36/150
# 125/125 [==============================] - 0s 734us/step - loss: 0.0070
# Epoch 37/150
# 125/125 [==============================] - 0s 804us/step - loss: 0.0076
# Epoch 38/150
# 125/125 [==============================] - 0s 799us/step - loss: 0.0082
# Epoch 39/150
# 125/125 [==============================] - 0s 871us/step - loss: 0.0062
# Epoch 40/150
# 125/125 [==============================] - 0s 875us/step - loss: 0.0072
# Epoch 41/150
# 125/125 [==============================] - 0s 839us/step - loss: 0.0072
# Epoch 42/150
# 125/125 [==============================] - 0s 809us/step - loss: 0.0078
# Epoch 43/150
# 125/125 [==============================] - 0s 832us/step - loss: 0.0061
# Epoch 44/150
# 125/125 [==============================] - 0s 863us/step - loss: 0.0060
# Epoch 45/150
# 125/125 [==============================] - 0s 854us/step - loss: 0.0068
# Epoch 46/150
# 125/125 [==============================] - 0s 888us/step - loss: 0.0060
# Epoch 47/150
# 125/125 [==============================] - 0s 879us/step - loss: 0.0060
# Epoch 48/150
# 125/125 [==============================] - 0s 854us/step - loss: 0.0053
# Epoch 49/150
# 125/125 [==============================] - 0s 864us/step - loss: 0.0052
# Epoch 50/150
# 125/125 [==============================] - 0s 889us/step - loss: 0.0049
# Epoch 51/150
# 125/125 [==============================] - 0s 860us/step - loss: 0.0058
# Epoch 52/150
# 125/125 [==============================] - 0s 887us/step - loss: 0.0047
# Epoch 53/150
# 125/125 [==============================] - 0s 887us/step - loss: 0.0055
# Epoch 54/150
# 125/125 [==============================] - 0s 873us/step - loss: 0.0052
# Epoch 55/150
# 125/125 [==============================] - 0s 873us/step - loss: 0.0046
# Epoch 56/150
# 125/125 [==============================] - 0s 895us/step - loss: 0.0045
# Epoch 57/150
# 125/125 [==============================] - 0s 849us/step - loss: 0.0050
# Epoch 58/150
# 125/125 [==============================] - 0s 787us/step - loss: 0.0047
# Epoch 59/150
# 125/125 [==============================] - 0s 864us/step - loss: 0.0045
# Epoch 60/150
# 125/125 [==============================] - 0s 831us/step - loss: 0.0039
# Epoch 61/150
# 125/125 [==============================] - 0s 834us/step - loss: 0.0046
# Epoch 62/150
# 125/125 [==============================] - 0s 862us/step - loss: 0.0057
# Epoch 63/150
# 125/125 [==============================] - 0s 867us/step - loss: 0.0055
# Epoch 64/150
# 125/125 [==============================] - 0s 840us/step - loss: 0.0043
# Epoch 65/150
# 125/125 [==============================] - 0s 853us/step - loss: 0.0038
# Epoch 66/150
# 125/125 [==============================] - 0s 844us/step - loss: 0.0035
# Epoch 67/150
# 125/125 [==============================] - 0s 863us/step - loss: 0.0035
# Epoch 68/150
# 125/125 [==============================] - 0s 855us/step - loss: 0.0040
# Epoch 69/150
# 125/125 [==============================] - 0s 839us/step - loss: 0.0041
# Epoch 70/150
# 125/125 [==============================] - 0s 840us/step - loss: 0.0035
# Epoch 71/150
# 125/125 [==============================] - 0s 872us/step - loss: 0.0040
# Epoch 72/150
# 125/125 [==============================] - 0s 863us/step - loss: 0.0033
# Epoch 73/150
# 125/125 [==============================] - 0s 834us/step - loss: 0.0037
# Epoch 74/150
# 125/125 [==============================] - 0s 820us/step - loss: 0.0034
# Epoch 75/150
# 125/125 [==============================] - 0s 826us/step - loss: 0.0029
# Epoch 76/150
# 125/125 [==============================] - 0s 813us/step - loss: 0.0035
# Epoch 77/150
# 125/125 [==============================] - 0s 831us/step - loss: 0.0033
# Epoch 78/150
# 125/125 [==============================] - 0s 819us/step - loss: 0.0033
# Epoch 79/150
# 125/125 [==============================] - 0s 851us/step - loss: 0.0034
# Epoch 80/150
# 125/125 [==============================] - 0s 928us/step - loss: 0.0035
# Epoch 81/150
# 125/125 [==============================] - 0s 857us/step - loss: 0.0028
# Epoch 82/150
# 125/125 [==============================] - 0s 846us/step - loss: 0.0029
# Epoch 83/150
# 125/125 [==============================] - 0s 859us/step - loss: 0.0034
# Epoch 84/150
# 125/125 [==============================] - 0s 826us/step - loss: 0.0029
# Epoch 85/150
# 125/125 [==============================] - 0s 866us/step - loss: 0.0028
# Epoch 86/150
# 125/125 [==============================] - 0s 834us/step - loss: 0.0031
# Epoch 87/150
# 125/125 [==============================] - 0s 881us/step - loss: 0.0044
# Epoch 88/150
# 125/125 [==============================] - 0s 867us/step - loss: 0.0037
# Epoch 89/150
# 125/125 [==============================] - 0s 876us/step - loss: 0.0032
# Epoch 90/150
# 125/125 [==============================] - 0s 780us/step - loss: 0.0023
# Epoch 91/150
# 125/125 [==============================] - 0s 853us/step - loss: 0.0026
# Epoch 92/150
# 125/125 [==============================] - 0s 855us/step - loss: 0.0023
# Epoch 93/150
# 125/125 [==============================] - 0s 850us/step - loss: 0.0030
# Epoch 94/150
# 125/125 [==============================] - 0s 884us/step - loss: 0.0026
# Epoch 95/150
# 125/125 [==============================] - 0s 857us/step - loss: 0.0028
# Epoch 96/150
# 125/125 [==============================] - 0s 856us/step - loss: 0.0022
# Epoch 97/150
# 125/125 [==============================] - 0s 857us/step - loss: 0.0024
# Epoch 98/150
# 125/125 [==============================] - 0s 848us/step - loss: 0.0029
# Epoch 99/150
# 125/125 [==============================] - 0s 846us/step - loss: 0.0023
# Epoch 100/150
# 125/125 [==============================] - 0s 861us/step - loss: 0.0027
# Epoch 101/150
# 125/125 [==============================] - 0s 850us/step - loss: 0.0025
# Epoch 102/150
# 125/125 [==============================] - 0s 861us/step - loss: 0.0026
# Epoch 103/150
# 125/125 [==============================] - 0s 839us/step - loss: 0.0024
# Epoch 104/150
# 125/125 [==============================] - 0s 857us/step - loss: 0.0024
# Epoch 105/150
# 125/125 [==============================] - 0s 871us/step - loss: 0.0028
# Epoch 106/150
# 125/125 [==============================] - 0s 852us/step - loss: 0.0026
# Epoch 107/150
# 125/125 [==============================] - 0s 837us/step - loss: 0.0021
# Epoch 108/150
# 125/125 [==============================] - 0s 842us/step - loss: 0.0031
# Epoch 109/150
# 125/125 [==============================] - 0s 837us/step - loss: 0.0027
# Epoch 110/150
# 125/125 [==============================] - 0s 822us/step - loss: 0.0020
# Epoch 111/150
# 125/125 [==============================] - 0s 848us/step - loss: 0.0029
# Epoch 112/150
# 125/125 [==============================] - 0s 839us/step - loss: 0.0021
# Epoch 113/150
# 125/125 [==============================] - 0s 831us/step - loss: 0.0026
# Epoch 114/150
# 125/125 [==============================] - 0s 846us/step - loss: 0.0020
# Epoch 115/150
# 125/125 [==============================] - 0s 809us/step - loss: 0.0026
# Epoch 116/150
# 125/125 [==============================] - 0s 833us/step - loss: 0.0023
# Epoch 117/150
# 125/125 [==============================] - 0s 815us/step - loss: 0.0029
# Epoch 118/150
# 125/125 [==============================] - 0s 814us/step - loss: 0.0019
# Epoch 119/150
# 125/125 [==============================] - 0s 829us/step - loss: 0.0020
# Epoch 120/150
# 125/125 [==============================] - 0s 809us/step - loss: 0.0018
# Epoch 121/150
# 125/125 [==============================] - 0s 840us/step - loss: 0.0022
# Epoch 122/150
# 125/125 [==============================] - 0s 841us/step - loss: 0.0017
# Epoch 123/150
# 125/125 [==============================] - 0s 865us/step - loss: 0.0022
# Epoch 124/150
# 125/125 [==============================] - 0s 859us/step - loss: 0.0019
# Epoch 125/150
# 125/125 [==============================] - 0s 869us/step - loss: 0.0019
# Epoch 126/150
# 125/125 [==============================] - 0s 860us/step - loss: 0.0021
# Epoch 127/150
# 125/125 [==============================] - 0s 832us/step - loss: 0.0017
# Epoch 128/150
# 125/125 [==============================] - 0s 856us/step - loss: 0.0027
# Epoch 129/150
# 125/125 [==============================] - 0s 865us/step - loss: 0.0024
# Epoch 130/150
# 125/125 [==============================] - 0s 892us/step - loss: 0.0023
# Epoch 131/150
# 125/125 [==============================] - 0s 891us/step - loss: 0.0020
# Epoch 132/150
# 125/125 [==============================] - 0s 854us/step - loss: 0.0018
# Epoch 133/150
# 125/125 [==============================] - 0s 829us/step - loss: 0.0017
# Epoch 134/150
# 125/125 [==============================] - 0s 860us/step - loss: 0.0017
# Epoch 135/150
# 125/125 [==============================] - 0s 845us/step - loss: 0.0016
# Epoch 136/150
# 125/125 [==============================] - 0s 852us/step - loss: 0.0017
# Epoch 137/150
# 125/125 [==============================] - 0s 847us/step - loss: 0.0017
# Epoch 138/150
# 125/125 [==============================] - 0s 864us/step - loss: 0.0018
# Epoch 139/150
# 125/125 [==============================] - 0s 841us/step - loss: 0.0025
# Epoch 140/150
# 125/125 [==============================] - 0s 865us/step - loss: 0.0024
# Epoch 141/150
# 125/125 [==============================] - 0s 858us/step - loss: 0.0016
# Epoch 142/150
# 125/125 [==============================] - 0s 846us/step - loss: 0.0018
# Epoch 143/150
# 125/125 [==============================] - 0s 838us/step - loss: 0.0016
# Epoch 144/150
# 125/125 [==============================] - 0s 827us/step - loss: 0.0021
# Epoch 145/150
# 125/125 [==============================] - 0s 846us/step - loss: 0.0016
# Epoch 146/150
# 125/125 [==============================] - 0s 835us/step - loss: 0.0026
# Epoch 147/150
# 125/125 [==============================] - 0s 837us/step - loss: 0.0015
# Epoch 148/150
# 125/125 [==============================] - 0s 817us/step - loss: 0.0025
# Epoch 149/150
# 125/125 [==============================] - 0s 833us/step - loss: 0.0014
# Epoch 150/150
# 125/125 [==============================] - 0s 848us/step - loss: 0.0016

# %%
DNmodelN = tf.keras.Sequential()

DNmodelN.add(tf.keras.layers.Dense(22, input_dim=XN_train_s.shape[1], activation='tanh'))
DNmodelN.add(tf.keras.layers.Dense(26, activation='tanh'))
DNmodelN.add(tf.keras.layers.Dense(30, activation='tanh'))
DNmodelN.add(tf.keras.layers.Dense(30, activation='tanh'))
DNmodelN.add(tf.keras.layers.Dense(30, activation='tanh'))
DNmodelN.add(tf.keras.layers.Dense(3))

DNmodelN.compile(loss="mean_squared_error", optimizer="adam")

DNmodelN.fit(XN_train_s, y_train, epochs= 150)
# Out:
# Epoch 1/150
# 125/125 [==============================] - 0s 1ms/step - loss: 3.5316
# Epoch 2/150
# 125/125 [==============================] - 0s 830us/step - loss: 0.4777
# Epoch 3/150
# 125/125 [==============================] - 0s 810us/step - loss: 0.3459
# Epoch 4/150
# 125/125 [==============================] - 0s 828us/step - loss: 0.2366
# Epoch 5/150
# 125/125 [==============================] - 0s 854us/step - loss: 0.1528
# Epoch 6/150
# 125/125 [==============================] - 0s 850us/step - loss: 0.1008
# Epoch 7/150
# 125/125 [==============================] - 0s 834us/step - loss: 0.0734
# Epoch 8/150
# 125/125 [==============================] - 0s 856us/step - loss: 0.0618
# Epoch 9/150
# 125/125 [==============================] - 0s 896us/step - loss: 0.0524
# Epoch 10/150
# 125/125 [==============================] - 0s 854us/step - loss: 0.0475
# Epoch 11/150
# 125/125 [==============================] - 0s 778us/step - loss: 0.0431
# Epoch 12/150
# 125/125 [==============================] - 0s 829us/step - loss: 0.0416
# Epoch 13/150
# 125/125 [==============================] - 0s 1ms/step - loss: 0.0394
# Epoch 14/150
# 125/125 [==============================] - 0s 886us/step - loss: 0.0376
# Epoch 15/150
# 125/125 [==============================] - 0s 832us/step - loss: 0.0378
# Epoch 16/150
# 125/125 [==============================] - 0s 847us/step - loss: 0.0354
# Epoch 17/150
# 125/125 [==============================] - 0s 831us/step - loss: 0.0362
# Epoch 18/150
# 125/125 [==============================] - 0s 762us/step - loss: 0.0359
# Epoch 19/150
# 125/125 [==============================] - 0s 836us/step - loss: 0.0339
# Epoch 20/150
# 125/125 [==============================] - 0s 925us/step - loss: 0.0337
# Epoch 21/150
# 125/125 [==============================] - 0s 874us/step - loss: 0.0333
# Epoch 22/150
# 125/125 [==============================] - 0s 837us/step - loss: 0.0337
# Epoch 23/150
# 125/125 [==============================] - 0s 850us/step - loss: 0.0329
# Epoch 24/150
# 125/125 [==============================] - 0s 829us/step - loss: 0.0324
# Epoch 25/150
# 125/125 [==============================] - 0s 856us/step - loss: 0.0317
# Epoch 26/150
# 125/125 [==============================] - 0s 812us/step - loss: 0.0323
# Epoch 27/150
# 125/125 [==============================] - 0s 848us/step - loss: 0.0319
# Epoch 28/150
# 125/125 [==============================] - 0s 811us/step - loss: 0.0319
# Epoch 29/150
# 125/125 [==============================] - 0s 866us/step - loss: 0.0310
# Epoch 30/150
# 125/125 [==============================] - 0s 831us/step - loss: 0.0311
# Epoch 31/150
# 125/125 [==============================] - 0s 830us/step - loss: 0.0304
# Epoch 32/150
# 125/125 [==============================] - 0s 914us/step - loss: 0.0298
# Epoch 33/150
# 125/125 [==============================] - 0s 872us/step - loss: 0.0301
# Epoch 34/150
# 125/125 [==============================] - 0s 830us/step - loss: 0.0303
# Epoch 35/150
# 125/125 [==============================] - 0s 865us/step - loss: 0.0296
# Epoch 36/150
# 125/125 [==============================] - 0s 853us/step - loss: 0.0286
# Epoch 37/150
# 125/125 [==============================] - 0s 851us/step - loss: 0.0300
# Epoch 38/150
# 125/125 [==============================] - 0s 856us/step - loss: 0.0288
# Epoch 39/150
# 125/125 [==============================] - 0s 854us/step - loss: 0.0286
# Epoch 40/150
# 125/125 [==============================] - 0s 833us/step - loss: 0.0288
# Epoch 41/150
# 125/125 [==============================] - 0s 845us/step - loss: 0.0288
# Epoch 42/150
# 125/125 [==============================] - 0s 862us/step - loss: 0.0282
# Epoch 43/150
# 125/125 [==============================] - 0s 915us/step - loss: 0.0292
# Epoch 44/150
# 125/125 [==============================] - 0s 874us/step - loss: 0.0281
# Epoch 45/150
# 125/125 [==============================] - 0s 850us/step - loss: 0.0272
# Epoch 46/150
# 125/125 [==============================] - 0s 848us/step - loss: 0.0294
# Epoch 47/150
# 125/125 [==============================] - 0s 842us/step - loss: 0.0282
# Epoch 48/150
# 125/125 [==============================] - 0s 833us/step - loss: 0.0283
# Epoch 49/150
# 125/125 [==============================] - 0s 854us/step - loss: 0.0274
# Epoch 50/150
# 125/125 [==============================] - 0s 865us/step - loss: 0.0277
# Epoch 51/150
# 125/125 [==============================] - 0s 839us/step - loss: 0.0270
# Epoch 52/150
# 125/125 [==============================] - 0s 853us/step - loss: 0.0272
# Epoch 53/150
# 125/125 [==============================] - 0s 826us/step - loss: 0.0283
# Epoch 54/150
# 125/125 [==============================] - 0s 855us/step - loss: 0.0287
# Epoch 55/150
# 125/125 [==============================] - 0s 825us/step - loss: 0.0276
# Epoch 56/150
# 125/125 [==============================] - 0s 807us/step - loss: 0.0276
# Epoch 57/150
# 125/125 [==============================] - 0s 847us/step - loss: 0.0273
# Epoch 58/150
# 125/125 [==============================] - 0s 877us/step - loss: 0.0268
# Epoch 59/150
# 125/125 [==============================] - 0s 835us/step - loss: 0.0282
# Epoch 60/150
# 125/125 [==============================] - 0s 828us/step - loss: 0.0262
# Epoch 61/150
# 125/125 [==============================] - 0s 831us/step - loss: 0.0285
# Epoch 62/150
# 125/125 [==============================] - 0s 805us/step - loss: 0.0262
# Epoch 63/150
# 125/125 [==============================] - 0s 809us/step - loss: 0.0260
# Epoch 64/150
# 125/125 [==============================] - 0s 833us/step - loss: 0.0265
# Epoch 65/150
# 125/125 [==============================] - 0s 833us/step - loss: 0.0270
# Epoch 66/150
# 125/125 [==============================] - 0s 788us/step - loss: 0.0263
# Epoch 67/150
# 125/125 [==============================] - 0s 807us/step - loss: 0.0268
# Epoch 68/150
# 125/125 [==============================] - 0s 869us/step - loss: 0.0257
# Epoch 69/150
# 125/125 [==============================] - 0s 829us/step - loss: 0.0257
# Epoch 70/150
# 125/125 [==============================] - 0s 802us/step - loss: 0.0261
# Epoch 71/150
# 125/125 [==============================] - 0s 820us/step - loss: 0.0268
# Epoch 72/150
# 125/125 [==============================] - 0s 832us/step - loss: 0.0265
# Epoch 73/150
# 125/125 [==============================] - 0s 776us/step - loss: 0.0260
# Epoch 74/150
# 125/125 [==============================] - 0s 840us/step - loss: 0.0258
# Epoch 75/150
# 125/125 [==============================] - 0s 804us/step - loss: 0.0268
# Epoch 76/150
# 125/125 [==============================] - 0s 883us/step - loss: 0.0263
# Epoch 77/150
# 125/125 [==============================] - 0s 833us/step - loss: 0.0264
# Epoch 78/150
# 125/125 [==============================] - 0s 839us/step - loss: 0.0257
# Epoch 79/150
# 125/125 [==============================] - 0s 830us/step - loss: 0.0252
# Epoch 80/150
# 125/125 [==============================] - 0s 828us/step - loss: 0.0258
# Epoch 81/150
# 125/125 [==============================] - 0s 824us/step - loss: 0.0264
# Epoch 82/150
# 125/125 [==============================] - 0s 809us/step - loss: 0.0263
# Epoch 83/150
# 125/125 [==============================] - 0s 839us/step - loss: 0.0255
# Epoch 84/150
# 125/125 [==============================] - 0s 844us/step - loss: 0.0269
# Epoch 85/150
# 125/125 [==============================] - 0s 840us/step - loss: 0.0253
# Epoch 86/150
# 125/125 [==============================] - 0s 824us/step - loss: 0.0258
# Epoch 87/150
# 125/125 [==============================] - 0s 803us/step - loss: 0.0250
# Epoch 88/150
# 125/125 [==============================] - 0s 825us/step - loss: 0.0258
# Epoch 89/150
# 125/125 [==============================] - 0s 839us/step - loss: 0.0251
# Epoch 90/150
# 125/125 [==============================] - 0s 832us/step - loss: 0.0248
# Epoch 91/150
# 125/125 [==============================] - 0s 886us/step - loss: 0.0253
# Epoch 92/150
# 125/125 [==============================] - 0s 825us/step - loss: 0.0262
# Epoch 93/150
# 125/125 [==============================] - 0s 818us/step - loss: 0.0247
# Epoch 94/150
# 125/125 [==============================] - 0s 808us/step - loss: 0.0255
# Epoch 95/150
# 125/125 [==============================] - 0s 827us/step - loss: 0.0247
# Epoch 96/150
# 125/125 [==============================] - 0s 803us/step - loss: 0.0255
# Epoch 97/150
# 125/125 [==============================] - 0s 836us/step - loss: 0.0248
# Epoch 98/150
# 125/125 [==============================] - 0s 823us/step - loss: 0.0256
# Epoch 99/150
# 125/125 [==============================] - 0s 810us/step - loss: 0.0258
# Epoch 100/150
# 125/125 [==============================] - 0s 805us/step - loss: 0.0248
# Epoch 101/150
# 125/125 [==============================] - 0s 826us/step - loss: 0.0251
# Epoch 102/150
# 125/125 [==============================] - 0s 821us/step - loss: 0.0250
# Epoch 103/150
# 125/125 [==============================] - 0s 865us/step - loss: 0.0252
# Epoch 104/150
# 125/125 [==============================] - 0s 844us/step - loss: 0.0263
# Epoch 105/150
# 125/125 [==============================] - 0s 820us/step - loss: 0.0248
# Epoch 106/150
# 125/125 [==============================] - 0s 808us/step - loss: 0.0245
# Epoch 107/150
# 125/125 [==============================] - 0s 814us/step - loss: 0.0255
# Epoch 108/150
# 125/125 [==============================] - 0s 811us/step - loss: 0.0247
# Epoch 109/150
# 125/125 [==============================] - 0s 801us/step - loss: 0.0261
# Epoch 110/150
# 125/125 [==============================] - 0s 853us/step - loss: 0.0245
# Epoch 111/150
# 125/125 [==============================] - 0s 851us/step - loss: 0.0242
# Epoch 112/150
# 125/125 [==============================] - 0s 811us/step - loss: 0.0242
# Epoch 113/150
# 125/125 [==============================] - 0s 871us/step - loss: 0.0243
# Epoch 114/150
# 125/125 [==============================] - 0s 839us/step - loss: 0.0252
# Epoch 115/150
# 125/125 [==============================] - 0s 859us/step - loss: 0.0251
# Epoch 116/150
# 125/125 [==============================] - 0s 744us/step - loss: 0.0246
# Epoch 117/150
# 125/125 [==============================] - 0s 922us/step - loss: 0.0247
# Epoch 118/150
# 125/125 [==============================] - 0s 835us/step - loss: 0.0248
# Epoch 119/150
# 125/125 [==============================] - 0s 818us/step - loss: 0.0243
# Epoch 120/150
# 125/125 [==============================] - 0s 828us/step - loss: 0.0247
# Epoch 121/150
# 125/125 [==============================] - 0s 811us/step - loss: 0.0245
# Epoch 122/150
# 125/125 [==============================] - 0s 818us/step - loss: 0.0244
# Epoch 123/150
# 125/125 [==============================] - 0s 835us/step - loss: 0.0246
# Epoch 124/150
# 125/125 [==============================] - 0s 824us/step - loss: 0.0243
# Epoch 125/150
# 125/125 [==============================] - 0s 826us/step - loss: 0.0247
# Epoch 126/150
# 125/125 [==============================] - 0s 822us/step - loss: 0.0242
# Epoch 127/150
# 125/125 [==============================] - 0s 850us/step - loss: 0.0247
# Epoch 128/150
# 125/125 [==============================] - 0s 823us/step - loss: 0.0245
# Epoch 129/150
# 125/125 [==============================] - 0s 848us/step - loss: 0.0247
# Epoch 130/150
# 125/125 [==============================] - 0s 810us/step - loss: 0.0248
# Epoch 131/150
# 125/125 [==============================] - 0s 846us/step - loss: 0.0240
# Epoch 132/150
# 125/125 [==============================] - 0s 855us/step - loss: 0.0243
# Epoch 133/150
# 125/125 [==============================] - 0s 881us/step - loss: 0.0240
# Epoch 134/150
# 125/125 [==============================] - 0s 865us/step - loss: 0.0237
# Epoch 135/150
# 125/125 [==============================] - 0s 878us/step - loss: 0.0244
# Epoch 136/150
# 125/125 [==============================] - 0s 876us/step - loss: 0.0234
# Epoch 137/150
# 125/125 [==============================] - 0s 806us/step - loss: 0.0244
# Epoch 138/150
# 125/125 [==============================] - 0s 807us/step - loss: 0.0242
# Epoch 139/150
# 125/125 [==============================] - 0s 825us/step - loss: 0.0253
# Epoch 140/150
# 125/125 [==============================] - 0s 868us/step - loss: 0.0247
# Epoch 141/150
# 125/125 [==============================] - 0s 868us/step - loss: 0.0237
# Epoch 142/150
# 125/125 [==============================] - 0s 850us/step - loss: 0.0240
# Epoch 143/150
# 125/125 [==============================] - 0s 830us/step - loss: 0.0238
# Epoch 144/150
# 125/125 [==============================] - 0s 819us/step - loss: 0.0246
# Epoch 145/150
# 125/125 [==============================] - 0s 844us/step - loss: 0.0232
# Epoch 146/150
# 125/125 [==============================] - 0s 762us/step - loss: 0.0242
# Epoch 147/150
# 125/125 [==============================] - 0s 819us/step - loss: 0.0236
# Epoch 148/150
# 125/125 [==============================] - 0s 806us/step - loss: 0.0236
# Epoch 149/150
# 125/125 [==============================] - 0s 784us/step - loss: 0.0239
# Epoch 150/150
# 125/125 [==============================] - 0s 848us/step - loss: 0.0239

# %%
DNmodelA_pred = DNmodelA.predict(XA_test_s)
DNmodelN_pred = DNmodelN.predict(XN_test_s)
# Out:
# 54/54 [==============================] - 0s 841us/step
# 54/54 [==============================] - 0s 947us/step

# %%
evaldf_SRD(DNmodelA_pred, DNmodelN_pred, 'DN')
evaldf_ConSD(DNmodelA_pred, DNmodelN_pred, 'DN')
evaldf_SCD(DNmodelA_pred, DNmodelN_pred, 'DN')

# %%
plot_result(DNmodelA_pred, DNmodelN_pred)

# %% [markdown]
# ### Performance Table

# %%
performance_SRD
# Out:
#      name     R^2_A     MAE_A    MAPE_A    RMSE_A     R^2_N     MAE_N  \
# 0  DT_SRD  0.997294  0.015638  0.003795  0.064721   0.99551  0.015158
# 1  RF_SRD  0.999357  0.015036  0.003522  0.031544  0.998183  0.018223
# 2  XG_SRD  0.999342   0.01648  0.003778  0.031924   0.99878  0.021415
# 3  SV_SRD  0.996522  0.060836   0.01311  0.073376  0.988253  0.096567
# 4  DN_SRD   0.99862  0.033607  0.006771  0.046226  0.988691  0.101462
#
#      MAPE_N    RMSE_N
# 0  0.003674  0.083377
# 1  0.004498  0.053044
# 2  0.005133  0.043466
# 3  0.021752  0.134859
# 4  0.022632  0.132323

# %%
performance_ConSD
# Out:
#         name     R^2_A     MAE_A    MAPE_A    RMSE_A     R^2_N     MAE_N  \
# 0  DT_ConsSD  0.999265  0.007175  0.003853  0.029584   0.99845  0.014649
# 1  RF_ConsSD  0.999767  0.008544  0.004391  0.016656  0.999116  0.015002
# 2  XG_ConsSD  0.999552  0.011423    0.0056  0.023105  0.999243  0.014771
# 3  SV_ConsSD  0.995443  0.061178  0.033704  0.073682  0.982607  0.110182
# 4  DN_ConsSD  0.998279  0.031619  0.014681  0.045285  0.981887  0.112858
#
#      MAPE_N    RMSE_N
# 0  0.005433  0.042966
# 1  0.006307  0.032448
# 2  0.006311  0.030037
# 3  0.059599  0.143944
# 4  0.060602  0.146893

# %%
performance_SCD
# Out:
#      name     R^2_A     MAE_A    MAPE_A    RMSE_A     R^2_N     MAE_N  \
# 0  DT_SCD  0.941458  0.109687  0.379711  0.174496  0.892017  0.157863
# 1  RF_SCD  0.978645  0.071328  0.456123  0.105389  0.940476  0.128844
# 2  XG_SCD  0.984334  0.057258  0.308705  0.090266  0.967092  0.089376
# 3  SV_SCD  0.993737  0.047019  0.275767  0.057075  0.919221  0.168389
# 4  DN_SCD  0.997717  0.026685  0.155864   0.03446  0.928654  0.156755
#
#      MAPE_N    RMSE_N
# 0  0.636279  0.236989
# 1  0.675928  0.175953
# 2  0.420662  0.130828
# 3  0.756183  0.204975
# 4  0.659426  0.192636

# %% [markdown]
# ### Some initial evaluations

# %% [markdown]
# ### Out of Sample evaluations

# %%
os = pd.read_excel('data/os_data.xlsx')

# %%
len(os)
# Out:
# 1740

# %%
os = os[os["LMTD"] > 0]

# %%
len(os)
# Out:
# 806

# %%
os = os[os["LA Chilling Duty"] >= 0]

# %%
len(os)
# Out:
# 793

# %%
os["SCD (MJ/kg)"] = (0.001 * os["LA Chilling Duty"]) / os["Captured CO2 (kg/h)"]

# %%
sns.displot(os["CO2 Capture Efficiency"], bins=15, kde=True)

# %%
os_inp_A = os[["FG Temperature", "Lean Loading",'Lean Amine Temperature','L/G (kg/kg)','Flue gas CO2 cons','CO2 Capture Efficiency','LMTD','Abs Height']]
os_inp_N = os[["FG Temperature", "Lean Loading",'Lean Amine Temperature','L/G (kg/kg)','Flue gas CO2 cons','CO2 Capture Efficiency']]

# %%
os_out = os[["SRD (MJ/kg CO2)", "Condensor Specific Duty", "SCD (MJ/kg)"]]

# %%
DTmodelA_ospred = DTmodelA.predict(os_inp_A)
RFmodelA_ospred = RFmodelA.predict(os_inp_A)
XGmodelA_ospred = XGmodelA.predict(os_inp_A)
SVmodelA_ospred = SVmodelA.predict(os_inp_A)
DNmodelA_ospred = DNmodelA.predict(scalerA.transform(os_inp_A))
# Out:
# 25/25 [==============================] - 0s 1ms/step

# %%
DTmodelN_ospred = DTmodelN.predict(os_inp_N)
RFmodelN_ospred = RFmodelN.predict(os_inp_N)
XGmodelN_ospred = XGmodelN.predict(os_inp_N)
SVmodelN_ospred = SVmodelN.predict(os_inp_N)
DNmodelN_ospred = DNmodelN.predict(scalerN.transform(os_inp_N))
# Out:
# 25/25 [==============================] - 0s 1ms/step

# %%
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], DTmodelA_ospred[: , 0]))
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], RFmodelA_ospred[: , 0]))
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], XGmodelA_ospred[: , 0]))
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], SVmodelA_ospred[: , 0]))
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], DNmodelA_ospred[: , 0]))
# Out:
# 0.07868726721373023
# 0.059749729415980134
# 0.05311514535057875
# 0.05338107102735113
# 0.03224648150080225

# %%
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], DTmodelN_ospred[: , 0]))
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], RFmodelN_ospred[: , 0]))
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], XGmodelN_ospred[: , 0]))
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], SVmodelN_ospred[: , 0]))
print(mean_absolute_percentage_error(os_out["SRD (MJ/kg CO2)"], DNmodelN_ospred[: , 0]))
# Out:
# 0.09898961810507308
# 0.0846638485908761
# 0.09114112265318809
# 0.0714166705612823
# 0.07348834670403975

# %%
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], DTmodelA_ospred[: , 1]))
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], RFmodelA_ospred[: , 1]))
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], XGmodelA_ospred[: , 1]))
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], SVmodelA_ospred[: , 1]))
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], DNmodelA_ospred[: , 1]))
# Out:
# 0.11908720106798498
# 0.10069903802464678
# 0.08226412739880715
# 0.1725757081898993
# 0.07041978460345771

# %%
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], DTmodelN_ospred[: , 1]))
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], RFmodelN_ospred[: , 1]))
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], XGmodelN_ospred[: , 1]))
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], SVmodelN_ospred[: , 1]))
print(mean_absolute_percentage_error(os_out["Condensor Specific Duty"], DNmodelN_ospred[: , 1]))
# Out:
# 0.16404036757827145
# 0.1540371416251606
# 0.15588266435135817
# 0.22945293470828815
# 0.12936317262011557

# %%
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], DTmodelA_ospred[: , 2]))
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], RFmodelA_ospred[: , 2]))
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], XGmodelA_ospred[: , 2]))
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], SVmodelA_ospred[: , 2]))
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], DNmodelA_ospred[: , 2]))
# Out:
# 0.5210212290443978
# 0.5124243219030662
# 0.49710104555999374
# 0.14472844844531363
# 0.05961466044863372

# %%
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], DTmodelN_ospred[: , 2]))
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], RFmodelN_ospred[: , 2]))
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], XGmodelN_ospred[: , 2]))
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], SVmodelN_ospred[: , 2]))
print(mean_absolute_percentage_error(os_out["SCD (MJ/kg)"], DNmodelN_ospred[: , 2]))
# Out:
# 0.5762274083025368
# 0.5043901151039446
# 0.5089007489825307
# 0.3332908209462706
# 0.4579816901561032
